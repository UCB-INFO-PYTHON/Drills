# %% [markdown]
# ## 2.4 The Anaconda Installation

# %% [markdown]
# ### Drills Note:
# - These drills/exercises are designed to give you more practice with Python and to help bridge the difficulty between the async and the homework assignments. They are optional but highly encouraged as a lot of programming skill comes from a certain familiarity and repetition with the code!
#
#
# ### This exercise notes:
#
# - To better understand what you have installed with the Anaconda distribution that you installed lets do some exploring. In order to run command line processes through this notebook we will preface the commands with "!". The "!" uses the IPython shortcut to launch command line processes. Because Jupyter notebooks use the IPython interpreters, we are able to do this, but it will not work with all python interpreters.
# - The following is the exploration and output on my machine. Run the same commands on your machine and modify them if necessary.
# - Since command line commands are different on Mac/Linux vs Windows, both commands are given (in separate blocks).
# - In code cells comments are prefaced by "#"

# %% [markdown]
# ### Getting the current working directory to see where you are

# %%
# whats wrong with this?
pwd

# %%
# get the current working directory to see where you are, use !  to get to the command line

# Mac/Linux
# !pwd

# %%
# Windows
# !echo %cd%

# %% [markdown]
# Gunnar's output:
#
# ```/Users/GunnarK/Dropbox/coderepos/BerkeleyMIDS/W200/W18_python_Current/Drills/week_01_drills```

# %% [markdown]
# ### Find out which python version
# - Note how I am running Python 3.7

# %%
# Will work for everything: Mac/Linux & Windows

# !python --version

# %% [markdown]
# Gunnar's output:
#
# ```Python 3.7.2 :: Anaconda, Inc.```

# %% [markdown]
# ### Find where the current python is

# %%
# Mac/Linux
# !which python

# %%
# Windows
# !where python

# %% [markdown]
# Gunnar's output:
#
# ```/Users/GunnarK/miniconda/bin/python.```

# %%
# Mac/Linux

# binaries (/bin) are the packages and modules that are installed for the 
# current binaries, look into your binaries folder

# Use the extension found above!
# !ls -al "/Users/GunnarK/miniconda/bin/"

# Look at some of these folders also note in my folder, some packages have 
# "symbolic links" noted by "->" to the actual package that will be used.

# %%
# Windows
# !dir "/Users/GunnarK/miniconda/bin/"

# %% [markdown]
# Gunnar's output:
#
# ```total 488520
# drwxr-xr-x  277 GunnarK  staff       9418 May 10 22:17 .
# drwxr-xr-x   25 GunnarK  staff        850 Feb 19 21:53 ..
# -rwxrwxr-x    2 GunnarK  staff        536 May 26  2017 .anaconda-navigator-post-link.sh
# -rwxrwxr-x    2 GunnarK  staff        142 May 26  2017 .anaconda-navigator-pre-unlink.sh
# -rwxr-xr-x    1 GunnarK  staff       9272 May 25  2017 .openssl-libcrypto-fix
# -rw-r--r--    1 GunnarK  staff        237 May 25  2017 .openssl-post-link.sh
# -rwxrwxr-x    2 GunnarK  staff        130 Dec 23  2016 .python.app-post-link.sh
# -rwxrwxr-x    2 GunnarK  staff         38 Dec 23  2016 .python.app-pre-unlink.sh
# -rwxrwxr-x    2 GunnarK  staff        280 May 17  2017 .qt-post-link.sh
# -rwxrwxr-x    2 GunnarK  staff        113 May 17  2017 .qt-pre-unlink.sh
# -rwxrwxr-x    2 GunnarK  staff         97 Mar  2  2017 .widgetsnbextension-post-link.sh
# -rwxrwxr-x    2 GunnarK  staff         98 Mar  2  2017 .widgetsnbextension-pre-unlink.sh
# lrwxr-xr-x    1 GunnarK  staff          8 Aug  3  2017 2to3 -> 2to3-3.6
# -rwxr-xr-x    1 GunnarK  staff        112 Aug  3  2017 2to3-3.6
# drwxr-xr-x    3 GunnarK  staff        102 Aug  5  2017 Assistant.app
# drwxr-xr-x    3 GunnarK  staff        102 Aug  5  2017 Designer.app
# drwxr-xr-x    3 GunnarK  staff        102 Aug  5  2017 Linguist.app
# -rwxrwxr-x    2 GunnarK  staff       3802 Feb  9 14:45 activate
# -rwxrwxr-x    1 GunnarK  staff        167 Aug  5  2017 anaconda
# -rwxrwxr-x    1 GunnarK  staff        169 Aug  5  2017 anaconda-navigator
# -rwxrwxr-x    1 GunnarK  staff        155 Aug  5  2017 anaconda-project
# -rwxrwxr-x    1 GunnarK  staff      12005 Aug  5  2017 asadmin
# -rwxrwxr-x    1 GunnarK  staff        167 Aug  5  2017 binstar
# -rwxrwxr-x    1 GunnarK  staff        154 Aug  5  2017 blaze-server
# -rwxrwxr-x    1 GunnarK  staff        143 Aug  5  2017 bokeh
# -rwxrwxr-x    1 GunnarK  staff       1571 Aug  5  2017 bundle_image
# -rwxrwxr-x    3 GunnarK  staff     111396 Mar 31  2017 bunzip2
# -rwxrwxr-x    3 GunnarK  staff     111396 Mar 31  2017 bzcat
# lrwxr-xr-x    1 GunnarK  staff          6 Aug  5  2017 bzcmp -> bzdiff
# -rwxrwxr-x    3 GunnarK  staff       2128 Mar 31  2017 bzdiff
# lrwxr-xr-x    1 GunnarK  staff          6 Aug  5  2017 bzegrep -> bzgrep
# lrwxr-xr-x    1 GunnarK  staff          6 Aug  5  2017 bzfgrep -> bzgrep
# -rwxrwxr-x    3 GunnarK  staff       1677 Mar 31  2017 bzgrep
# -rwxrwxr-x    3 GunnarK  staff     111396 Mar 31  2017 bzip2
# -rwxrwxr-x    3 GunnarK  staff      14788 Mar 31  2017 bzip2recover
# lrwxr-xr-x    1 GunnarK  staff          6 Aug  5  2017 bzless -> bzmore
# -rwxrwxr-x    3 GunnarK  staff       1259 Mar 31  2017 bzmore
# -rwxr-xr-x    1 GunnarK  staff       5128 Aug  3  2017 c_rehash
# -rwxrwxr-x    1 GunnarK  staff       3461 Aug  5  2017 cfadmin
# -rwxrwxr-x    1 GunnarK  staff        159 Aug  5  2017 chardetect
# -rwxr-xr-x    4 GunnarK  staff      41296 Apr 15  2016 cjpeg
# -rwxrwxr-x    1 GunnarK  staff        133 Feb 19 21:53 conda
# -rwxrwxr-x    1 GunnarK  staff        151 Feb 19 21:53 conda-env
# -rwxrwxr-x    1 GunnarK  staff        167 Aug  5  2017 conda-server
# -rwxrwxr-x    1 GunnarK  staff       3070 Aug  5  2017 cq
# -rwxrwxr-x    1 GunnarK  staff        561 Aug  5  2017 createfontdatachunk.py
# -rwxrwxr-x    2 GunnarK  staff     189428 Jan 17  2017 curl
# -rwxrwxr-x    1 GunnarK  staff       5256 Aug  5  2017 curl-config
# -rwxrwxr-x    1 GunnarK  staff       5062 Aug  5  2017 cwutil
# -rwxrwxr-x    1 GunnarK  staff        157 Aug  5  2017 cygdb
# -rwxrwxr-x    1 GunnarK  staff        166 Aug  5  2017 cython
# -rwxrwxr-x    1 GunnarK  staff        159 Aug  5  2017 cythonize
# -rwxrwxr-x    1 GunnarK  staff        167 Aug  5  2017 dask-remote
# -rwxrwxr-x    1 GunnarK  staff        173 Aug  5  2017 dask-scheduler
# -rwxrwxr-x    1 GunnarK  staff        161 Aug  5  2017 dask-ssh
# -rwxrwxr-x    1 GunnarK  staff        167 Aug  5  2017 dask-submit
# -rwxrwxr-x    1 GunnarK  staff        167 Aug  5  2017
# -rwxrwxr-x    1 GunnarK  staff     274008 Aug  5  2017 h5repack
# -rwxrwxr-x    1 GunnarK  staff      22836 Aug  5  2017 h5repart
# -rwxrwxr-x    1 GunnarK  staff     187640 Aug  5  2017 h5stat
# -rwxrwxr-x    1 GunnarK  staff     170280 Aug  5  2017 h5unjam
# -rwxr-xr-x    1 GunnarK  staff      33744 Mar 16  2016 iconv
# -rwxrwxr-x    1 GunnarK  staff      22667 Aug  5  2017 icu-config
# -rwxrwxr-x    2 GunnarK  staff      13840 May 20  2015 icuinfo
# lrwxr-xr-x    1 GunnarK  staff          7 Aug  3  2017 idle3 -> idle3.6
# -rwxr-xr-x    1 GunnarK  staff        110 Aug  3  2017 idle3.6
# -rwxrwxr-x    1 GunnarK  staff       5795 Aug  5  2017 instance_events
# -rwxrwxr-x    1 GunnarK  staff        254 Aug  5  2017 iptest
# -rwxrwxr-x    1 GunnarK  staff        254 Aug  5  2017 iptest3
# -rwxrwxr-x    1 GunnarK  staff        138 Aug  5  2017 ipython
# -rwxrwxr-x    1 GunnarK  staff        138 Aug  5  2017 ipython3
# -rwxrwxr-x    1 GunnarK  staff        391 Aug  5  2017 isort
# -rwxrwxr-x    2 GunnarK  staff      37736 Mar  4  2017 isql
# -rwxrwxr-x    1 GunnarK  staff      11725 Aug  5  2017 isympy
# -rwxrwxr-x    2 GunnarK  staff      32384 Mar  4  2017 iusql
# -rwxrwxr-x    1 GunnarK  staff       1694 Aug  5  2017 jp.py
# -rwxr-xr-x    4 GunnarK  staff      45864 Apr 15  2016 jpegtran
# -rwxrwxr-x    1 GunnarK  staff        143 Aug  5  2017 jsonschema
# -rwxrwxr-x    1 GunnarK  staff        155 Aug  5  2017 jupyter
# -rwxrwxr-x    1 GunnarK  staff        256 Aug  5  2017 jupyter-bundlerextension
# -rwxrwxr-x    1 GunnarK  staff        153 Aug  5  2017 jupyter-console
# -rwxrwxr-x    1 GunnarK  staff        196 Aug  5  2017 jupyter-kernelspec
# -rwxrwxr-x    1 GunnarK  staff        155 Aug  5  2017 jupyter-migrate
# -rwxrwxr-x    1 GunnarK  staff        159 Aug  5  2017 jupyter-nbconvert
# -rwxrwxr-x    1 GunnarK  staff        157 Aug  5  2017 jupyter-nbextension
# -rwxrwxr-x    1 GunnarK  staff        155 Aug  5  2017 jupyter-notebook
# -rwxrwxr-x    1 GunnarK  staff        117 Aug  5  2017 jupyter-qtconsole
# -rwxrwxr-x    1 GunnarK  staff        157 Aug  5  2017 jupyter-run
# -rwxrwxr-x    1 GunnarK  staff        165 Aug  5  2017 jupyter-serverextension
# -rwxrwxr-x    1 GunnarK  staff        165 Aug  5  2017 jupyter-troubleshoot
# -rwxrwxr-x    1 GunnarK  staff        169 Aug  5  2017 jupyter-trust
# -rwxrwxr-x    1 GunnarK  staff        941 Aug  5  2017 kill_instance
# -rwxrwxr-x    1 GunnarK  staff      10622 Aug  5  2017 launch_instance
# -rwxrwxr-x    2 GunnarK  staff     269316 Nov 17  2016 lconvert
# lrwxr-xr-x    1 GunnarK  staff         15 Aug  5  2017 libpng-config -> libpng16-config
# -rwxrwxr-x    1 GunnarK  staff       2333 Aug  5  2017 libpng16-config
# -rwxrwxr-x    1 GunnarK  staff       3115 Aug  5  2017 list_instances
# -rwxrwxr-x    2 GunnarK  staff     526920 Nov 17  2016 lrelease
# -rwxr-xr-x    1 GunnarK  staff        230 Dec 31 02:19 pyfiglet
# -rwxrwxr-x    1 GunnarK  staff        406 Aug  5  2017 pyflakes
# -rwxrwxr-x    1 GunnarK  staff        147 Aug  5  2017 pygmentize
# -rwxrwxr-x    1 GunnarK  staff        133 Aug  5  2017 pylint
# -rwxrwxr-x    1 GunnarK  staff        137 Aug  5  2017 pylint-gui
# -rwxrwxr-x    1 GunnarK  staff     224376 Aug  5  2017 pylupdate5
# -rwxrwxr-x    1 GunnarK  staff      66880 Aug  5  2017 pyrcc5
# -rwxrwxr-x    1 GunnarK  staff        136 Aug  5  2017 pyreverse
# -rwxrwxr-x    1 GunnarK  staff        396 Aug  5  2017 pytest
# lrwxr-xr-x    1 GunnarK  staff          9 Aug  3  2017 python -> python3.6
# -rwxrwxr-x    1 GunnarK  staff        135 Aug  5  2017 python.app
# lrwxr-xr-x    1 GunnarK  staff          9 Aug  3  2017 python3 -> python3.6
# lrwxr-xr-x    1 GunnarK  staff         17 Aug  3  2017 python3-config -> python3.6m-config
# -rwxr-xr-x    1 GunnarK  staff       9500 May 11  2017 python3.6
# lrwxr-xr-x    1 GunnarK  staff         17 Aug  3  2017 python3.6-config -> python3.6m-config
# -rwxr-xr-x    2 GunnarK  staff       9500 May 11  2017 python3.6m
# -rwxr-xr-x    1 GunnarK  staff       2052 Aug  3  2017 python3.6m-config
# -rwxrwxr-x    1 GunnarK  staff        135 Aug  5  2017 pythonw
# -rwxrwxr-x    5 GunnarK  staff         54 Jun  7  2017 pyuic5
# lrwxr-xr-x    1 GunnarK  staff         10 Aug  3  2017 pyvenv -> pyvenv-3.6
# -rwxr-xr-x    1 GunnarK  staff        452 Aug  3  2017 pyvenv-3.6
# -rwxrwxr-x    2 GunnarK  staff      73952 Nov 17  2016 qcollectiongenerator
# -rwxrwxr-x    2 GunnarK  staff    1640088 Nov 17  2016 qdoc
# -rwxrwxr-x    2 GunnarK  staff     187332 Nov 17  2016 qhelpconverter
# -rwxrwxr-x    2 GunnarK  staff      35908 Nov 17  2016 qhelpgenerator
# -rwxrwxr-x    2 GunnarK  staff     146160 Nov 17  2016 qlalr
# -rwxrwxr-x    1 GunnarK  staff    4767228 Aug  5  2017 qmake
# drwxr-xr-x    3 GunnarK  staff        102 Aug  5  2017 qml.app
# -rwxrwxr-x    2 GunnarK  staff     119592 Nov 17  2016 qmleasing
# -rwxrwxr-x    2 GunnarK  staff     269476 Nov 17  2016 qmlimportscanner
# -rwxrwxr-x    2 GunnarK  staff     204044 Nov 17  2016 qmllint
# -rwxrwxr-x    2 GunnarK  staff     117092 Nov 17  2016 qmlmin
# -rwxrwxr-x    2 GunnarK  staff     166740 Nov 17  2016 qmlplugindump
# -rwxrwxr-x    2 GunnarK  staff     195892 Nov 17  2016 qmlprofiler
# -rwxrwxr-x    2 GunnarK  staff      65324 Nov 17  2016 qmlscene
# -rwxrwxr-x    2 GunnarK  staff      29088 Nov 17  2016 qmltestrunner
# -rw-rw-r--    1 GunnarK  staff        172 Aug  5  2017 qt.conf
# -rwxrwxr-x    2 GunnarK  staff      74840 Nov 17  2016 qtdiag
# -rwxrwxr-x    2 GunnarK  staff      38732 Nov 17  2016 qtpaths
# -rwxrwxr-x    2 GunnarK  staff      32540 Nov 17  2016 qtplugininfo
# -rwxrwxr-x    2 GunnarK  staff     856020 Nov 17  2016 rcc
# -rwxr-xr-x    4 GunnarK  staff      13652 Apr 15  2016 rdjpgcom
# -rwxrwxr-x    1 GunnarK  staff       9051 Aug  5  2017 route53
# -rwxrwxr-x    1 GunnarK  staff        613 Aug  5  2017 rst2html.py
# -rwxrwxr-x    1 GunnarK  staff       1159 Aug  5  2017 rst2html5.py
# -rwxrwxr-x    1 GunnarK  staff        810 Aug  5  2017 rst2latex.py
# -rwxrwxr-x    1 GunnarK  staff        619 Aug  5  2017 rst2man.py
# -rwxrwxr-x    1 GunnarK  staff        783 Aug  5  2017 rst2odt.py
# -rwxrwxr-x    1 GunnarK  staff       1717 Aug  5  2017 rst2odt_prepstyles.py
# -rwxrwxr-x    1 GunnarK  staff        620 Aug  5  2017 rst2pseudoxml.py
# -rwxrwxr-x    1 GunnarK  staff        656 Aug  5  2017 rst2s5.py
# -rwxrwxr-x    1 GunnarK  staff        890 Aug  5  2017 rst2xetex.py
# -rwxrwxr-x    1 GunnarK  staff        621 Aug  5  2017 rst2xml.py
# -rwxrwxr-x    1 GunnarK  staff        689 Aug  5  2017 rstpep2html.py
# -rwxrwxr-x    1 GunnarK  staff      16320 Aug  5  2017 runxlrd.py
# -rwxrwxr-x    1 GunnarK  staff      16856 Aug  5  2017 s3put
# -rwxrwxr-x    1 GunnarK  staff        167 Aug  5  2017 samp_hub
# -rwxrwxr-x    1 GunnarK  staff       7012 Aug  5  2017 sdbadmin
# -rwxrwxr-x    2 GunnarK  staff     350076 Jan 17  2017 sip
# -rwxrwxr-x    1 GunnarK  staff        157 Aug  5  2017 skivi
# -rwxrwxr-x    2 GunnarK  staff      17752 Mar  4  2017 slencheck
# -rwxrwxr-x    1 GunnarK  staff        410 Aug  5  2017 sphinx-apidoc
# -rwxrwxr-x    1 GunnarK  staff        412 Aug  5  2017 sphinx-autogen
# -rwxrwxr-x    1 GunnarK  staff        408 Aug  5  2017 sphinx-build
# -rwxrwxr-x    1 GunnarK  staff        418 Aug  5  2017 sphinx-quickstart
# -rwxrwxr-x    1 GunnarK  staff        158 Feb 19 21:53 spyder
# -rwxr-xr-x    2 GunnarK  staff    1432944 May 25  2016 sqlite3
# -rwxrwxr-x    1 GunnarK  staff        134 Aug  5  2017 symilar
# -rwxrwxr-x    2 GunnarK  staff      47182 Nov 17  2016 syncqt.pl
# -rwxrwxr-x    1 GunnarK  staff       3786 Aug  5  2017 taskadmin
# -rwxr-xr-x    2 GunnarK  staff      12712 Mar 16  2015 tclsh8.5
# -rwxrwxr-x    1 GunnarK  staff        183 Aug  5  2017 tensorboard
# -rwxrwxr-x    1 GunnarK  staff       2000 Aug  5  2017 thresholder.py
# -rwxrwxr-x    2 GunnarK  staff      46584 May 20  2015 uconv
# -rwxrwxr-x    2 GunnarK  staff     472568 Nov 17  2016 uic
# lrwxr-xr-x    1 GunnarK  staff          2 Aug  3  2017 unxz -> xz
# -rwxrwxr-x    1 GunnarK  staff       1972 Aug  5  2017 vba_extract.py
# -rwxrwxr-x    1 GunnarK  staff       1039 Aug  5  2017 viewer.py
# -rwxrwxr-x    1 GunnarK  staff        165 Aug  5  2017 volint
# -rwxrwxr-x    1 GunnarK  staff        153 Aug  5  2017 wcslint
# -rwxr-xr-x    1 GunnarK  staff        135 Aug  3  2017 wheel
# -rwxr-xr-x    2 GunnarK  staff      25160 Mar 16  2015 wish8.5
# -rwxr-xr-x    4 GunnarK  staff      13892 Apr 15  2016 wrjpgcom
# -rwxrwxr-x    1 GunnarK  staff        155 Aug  5  2017 xlwings
# -rwxrwxr-x    1 GunnarK  staff       1799 Aug  5  2017 xml2-config
# -rwxrwxr-x    1 GunnarK  staff      23620 Dec  8  2016 xmlcatalog
# -rwxrwxr-x    1 GunnarK  staff      82836 Dec  8  2016 xmllint
# -rwxrwxr-x    2 GunnarK  staff      84392 Nov 17  2016 xmlpatterns
# -rwxrwxr-x    2 GunnarK  staff      19168 Nov 17  2016 xmlpatternsvalidator
# -rwxr-xr-x    1 GunnarK  staff       2630 Aug  5  2017 xslt-config
# -rwxr-xr-x    1 GunnarK  staff      30200 Sep  1  2016 xsltproc
# -rwxr-xr-x    2 GunnarK  staff      96556 Dec 28  2016 xz```

# %% [markdown]
# ### The interpreter finds the packages by traversing the system path file
#
# This is why you had to append the path of the Anaconda code to the search path when you installed Anaconda
#
# Can you find the anaconda specific paths below?
#
# Can you find them in your workspace?

# %%
# Mac/linux:
# !echo $PATH

# %%
# Windows
# !echo %Path%

# %% [markdown]
# Gunnar's output:
#
# ```/Users/GunnarK/miniconda/bin:/Users/GunnarK/miniconda/bin:/Library/Frameworks/R.framework/Resources/bin/R:/Users/GunnarK/anaconda/envs/plotbio35/bin:/Library/Frameworks/Python.framework/Versions/2.7/bin:/Users/GunnarK/anaconda/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin:/Library/TeX/texbin:/usr/lpp/mmfs/bin:/usr/bin/java```

# %% [markdown]
# ### Finally, my system has separate conda environments built to have better control over dependencies.
# - Note the path to each environment. The ```*``` denotes the current environment
#
# Look at this on your system. Do you have any environments other then 'base'?
#
# If you want to try to make one:
# https://conda.io/docs/user-guide/tasks/manage-environments.html

# %%
# Will work for everything: Mac/Linux & Windows

# !conda info --envs

# %% [markdown]
# Gunnar's output:
#
# ```
# # conda environments:
# #
# AsuragenVPN              /Users/GunnarK/miniconda/envs/AsuragenVPN
# BioInf12_15              /Users/GunnarK/miniconda/envs/BioInf12_15
# Cytof                    /Users/GunnarK/miniconda/envs/Cytof
# Cytof2.7                 /Users/GunnarK/miniconda/envs/Cytof2.7
# NetWAS_2                 /Users/GunnarK/miniconda/envs/NetWAS_2
# Netwaspy2                /Users/GunnarK/miniconda/envs/Netwaspy2
# RBio12_15                /Users/GunnarK/miniconda/envs/RBio12_15
# biorevs                  /Users/GunnarK/miniconda/envs/biorevs
# grader35                 /Users/GunnarK/miniconda/envs/grader35
# opencvenv                /Users/GunnarK/miniconda/envs/opencvenv
# plotbio35                /Users/GunnarK/miniconda/envs/plotbio35
# py35jp                   /Users/GunnarK/miniconda/envs/py35jp
# py36                     /Users/GunnarK/miniconda/envs/py36
# py36jp                   /Users/GunnarK/miniconda/envs/py36jp
# pyNetWAS                 /Users/GunnarK/miniconda/envs/pyNetWAS
# tkinterenv               /Users/GunnarK/miniconda/envs/tkinterenv
# root                  *  /Users/GunnarK/miniconda```
