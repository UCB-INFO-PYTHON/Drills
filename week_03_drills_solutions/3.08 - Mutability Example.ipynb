# %% [markdown]
# Predict what the following cell with print.  Try drawing a diagram on paper showing all references.

# %%
A = ['a']
B = [A]
B.extend(A)
A[0] = 'e'

print(B)

# %% [markdown]
# Predict what the following cell will print.

# %%
A = ['a']
B = [A]
B.append(A)
A[0] = 'e'

print(B)

# %% [markdown]
# Predict what the following cell will print

# %%
A = ['nah']
B = [A,A]
C = B
D = [B,C]
B[0] = 'nee'
B[1] = 'ner'
print(D)
